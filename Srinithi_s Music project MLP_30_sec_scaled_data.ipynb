# %%
# Connect google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import libraries
import pandas as pd

# %%
train_dataset = pd.read_csv('/content/drive/Shareddrives/1:1 Srinithi Rajan/Dataset/Data/CSV files/train_scaled_30_sec.csv')

# %%
# Train a Random forest algorithm with 5-fold cross-validation
X = train_dataset.drop(['label'], axis =1)
y = train_dataset['label']

# %%
# import cross_val_score and Random forest
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier
import numpy as np

# MLP with learning rate and epochs
mlp = MLPClassifier(
    solver='adam',
    alpha=1e-5,
    hidden_layer_sizes=(5000, 10),
    learning_rate_init=0.005,  # Learning rate
    max_iter=100,  # Number of epochs
    random_state=1
)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(mlp, X, y, cv=5)

# Print the cross-validation scores for each fold
print(cv_scores)

# The average can be considered as the overall performance of the model
print("Average 5-Fold CV Score: ", np.mean(cv_scores))
# Please the average accuracy value into this sheet - https://docs.google.com/spreadsheets/d/1ly0Mgfquvcxa-1lU7bWTDoDEvc6t3ZZRrOL3DNBCtl8/edit?usp=sharing
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [0.90928996 0.91898655 0.93306225 0.94213325 0.93085106]
# ...

# %%
# Create a MLP classifier
import pickle
mlp = MLPClassifier(
    solver='adam',
    alpha=1e-5,
    hidden_layer_sizes=(5000, 10),
    learning_rate_init=0.005,  # Learning rate
    max_iter=100,  # Number of epochs
    random_state=1
)
mlp.fit(X,y)
with open("/content/drive/Shareddrives/1:1 Srinithi Rajan/Model/mlp_model_30sec_0.001_10.pkl","wb") as file:
  pickle.dump(mlp,file)
  file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2efb4bc671bd> in <cell line: 3>()
#       1 # Create a MLP classifier
#       2 import pickle
# ----> 3 mlp = MLPClassifier(
#       4     solver='adam',
#       5     alpha=1e-5,
#
# NameError: name 'MLPClassifier' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
